# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K
import pandas as pd
from sklearn.model_selection import train_test_split
import string
from string import digits
import re
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Input, Dense,Embedding, Concatenate, TimeDistributed
from tensorflow.keras.models import Model,load_model, model_from_json
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import EarlyStopping
import pickle as pkl
import numpy as np

# %%
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

# %%
# loading the model architecture and asigning the weights
json_file = open('NMT_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model_loaded = model_from_json(loaded_model_json, custom_objects={'AttentionLayer': AttentionLayer})
# load weights into new model
model_loaded.load_weights("NMT_model_weight.h5")

# %%
with open('NMT_Etokenizer.pkl','rb') as f:
  vocab_size_source, Eword2index, universal_translation_Tokenizer = pkl.load(f)

with open('NMT_Mtokenizer.pkl', 'rb') as f:
  vocab_size_target, Mword2index, archaic_translation_Tokenizer = pkl.load(f)

with open('NMT_data.pkl','rb') as f:
  X_train, y_train, X_test, y_test = pkl.load(f)

# %%
Eindex2word = universal_translation_Tokenizer.index_word
Mindex2word = archaic_translation_Tokenizer.index_word

# %%
latent_dim=500
# encoder inference
encoder_inputs = model_loaded.input[0]  #loading encoder_inputs
encoder_outputs, state_h, state_c = model_loaded.layers[6].output #loading encoder_outputs

print(encoder_outputs.shape)

encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(291,latent_dim))

# Get the embeddings of the decoder sequence
decoder_inputs = model_loaded.layers[3].output

print(decoder_inputs.shape)
dec_emb_layer = model_loaded.layers[5]

dec_emb2= dec_emb_layer(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_lstm = model_loaded.layers[7]
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_layer = model_loaded.layers[8]
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])

concate = model_loaded.layers[9]
decoder_inf_concat = concate([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_dense = model_loaded.layers[10]
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = Model(
[decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
[decoder_outputs2] + [state_h2, state_c2])
# Out:
# (None, 291, 500)
# (None, None)

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))

    # Chose the 'start' word as the first word of the target sequence
    target_seq[0, 0] = Mword2index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        if sampled_token_index == 0:
          break
        else:
          sampled_token = Mindex2word[sampled_token_index]

          if(sampled_token!='end'):
              decoded_sentence += ' '+sampled_token

              # Exit condition: either hit max length or find stop word.
              if (sampled_token == 'end' or len(decoded_sentence.split()) >= (101-1)):
                  stop_condition = True

          # Update the target sequence (of length 1).
          target_seq = np.zeros((1,1))
          target_seq[0, 0] = sampled_token_index

          # Update internal states
          e_h, e_c = h, c

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
      if((i!=0 and i!=Mword2index['start']) and i!=Mword2index['end']):
        newString=newString+Mindex2word[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
      if(i!=0):
        newString=newString+Eindex2word[i]+' '
    return newString

# %%
# !pip install jellyfish
# Out:
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (0.8.2)

# %%
# !pip install textdistance
# Out:
# Requirement already satisfied: textdistance in /usr/local/lib/python3.7/dist-packages (4.2.1)

# %%
# !pip install strsimpy
# Out:
# Requirement already satisfied: strsimpy in /usr/local/lib/python3.7/dist-packages (0.2.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import namedtuple
from nltk import word_tokenize
from functools import lru_cache
import re
import unicodedata
import sys
from collections import Counter
import nltk
nltk.download('brown')
from nltk.corpus import brown
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# !pip install transformers
# !pip install torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.8.2)
# Requirement already satisfied: huggingface-hub==0.0.12 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.5.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from transformers) (3.13)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2021.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub==0.0.12->transformers) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.5.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)

# %%
import torch
from transformers import BertTokenizer, BertModel, BertForMaskedLM

bert_model = 'bert-large-uncased'
tokenizer = BertTokenizer.from_pretrained(bert_model)
model = BertForMaskedLM.from_pretrained(bert_model)
model.eval()
# Out:
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 1024, padding_idx=0)
#       (position_embeddings): Embedding(512, 1024)
#       (token_type_embeddings): Embedding(2, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (12): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (13): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (14): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (15): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (16): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (17): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (18): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (19): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (20): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (21): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (22): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (23): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=1024, out_features=1024, bias=True)
#               (key): Linear(in_features=1024, out_features=1024, bias=True)
#               (value): Linear(in_features=1024, out_features=1024, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=1024, out_features=4096, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=4096, out_features=1024, bias=True)
#             (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (LayerNorm): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=1024, out_features=30522, bias=True)
#     )
#   )
# )

# %%
# !pip install wordfreq
# Out:
# Requirement already satisfied: wordfreq in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: langcodes>=3.0 in /usr/local/lib/python3.7/dist-packages (from wordfreq) (3.1.0)
# Requirement already satisfied: regex>=2020.04.04 in /usr/local/lib/python3.7/dist-packages (from wordfreq) (2021.7.1)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.7/dist-packages (from wordfreq) (1.0.2)

# %%
from wordfreq import zipf_frequency
zipf_frequency('stop', 'en')
# Out:
# 5.52

# %%
def get_bert_candidates(input_text, list_cwi_predictions, numb_predictions_displayed = 10):
  list_candidates_bert = []
  for word in input_text.split():
    # if ((pos_tag([word])[0][1] in ['NNS', 'NN', 'VBP', 'RB', 'VBG','VBD' ])  or (zipf_frequency(word, 'en')) <1):
    if (word == list_cwi_predictions):
      replace_word_mask = input_text.replace(word, '[MASK]')
      text = f'[CLS]{replace_word_mask} [SEP] {input_text} [SEP] '
      tokenized_text = tokenizer.tokenize(text)
      masked_index = [i for i, x in enumerate(tokenized_text) if x == '[MASK]'][0]
      indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
      segments_ids = [0]*len(tokenized_text)
      tokens_tensor = torch.tensor([indexed_tokens])
      segments_tensors = torch.tensor([segments_ids])
      # Predict all tokens
      with torch.no_grad():
          outputs = model(tokens_tensor, token_type_ids=segments_tensors)
          predictions = outputs[0][0][masked_index]
      predicted_ids = torch.argsort(predictions, descending=True)[:numb_predictions_displayed]
      predicted_tokens = tokenizer.convert_ids_to_tokens(list(predicted_ids))
      list_candidates_bert.append((word, predicted_tokens))
  return list_candidates_bert

# %%
import re
import jellyfish
import scipy
import textdistance
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from nltk.translate import bleu
from strsimpy.normalized_levenshtein import NormalizedLevenshtein
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from difflib import SequenceMatcher
from nltk.translate.bleu_score import SmoothingFunction
count_vect = CountVectorizer()
cc = SmoothingFunction() 
smoothie = SmoothingFunction().method4
sum=0
sum1=0
sum2=0
sum3=0
sum4=0
sum5=0
sum6=0
sum7=0
performance=0
performance1=0
aperformance2=0
performance3=0
performance4=0
performance5=0
performance6=0
performance7=0
normalized_levenshtein = NormalizedLevenshtein()
dct = {'deviant':'devaint (departing from usual or accepted standards)',
       'cessation':'end',
    'conspicuous':'visible',
    'repelling':'repelling (turning it back)',
    'calamity':'disaster',
    'merchandise':'goods',
    'impassioned':'imapassioned (filled with or showing great emotion)',
    'coercion':'force',
    'despaired':'lost hope',
    'adversity':'disaster',
    'exultant':'thrilled',
    'adorments':'glitter',
    'unto':'to',
    'depositories':'depositories (a place where things can be stored)',
    'anchorage':'anchorage (a place where the boat is or can be anchored)',
    'disembark':'disembark (to leave a ship after a journey)',
    'forelock':'forelock (a piece of hair that grows or falls over the forehead)',
    'obstinate':'aggressive',
    'tyrant':'cruel ruler',
    'disquieting':'alarming',
    'hamstrung':'killed',
    'shriek':'shriek (a piercing cry or blast from the sky)',
    'apprehension':'harm',
    'availed':'profited',
    'bestowal':'gift',
    'undiminished':'fully',
    'impending':'impending (near)',
    'tyranny':'oppression',
    'enmity':'extreme hatred',
    'ambush':'attack',
    'besiege':'surround',
    'kinship':'relationship',
    'striven':'striven (make great efforts to achieve something)',
    'commerce':'trade',
    'flanks':'flanks (the side of a persons or animals body between the ribs and the hips)',
    'tranquility':'calm',
    'apprehensive':'anxious',
    'vanities':'idle talks',
    'stingy':'not generous',
    'bedouins':'bedouins (a member of an Arab people living in or near the desert)',
    'invocations':'prayers',
    'afflicted':'suffered',
    'inflictions':'imposed',
    'wherein':'in which',
    'therewith':'therewith (soon or immediately after that)',
    'hostilities':'hostilities (hatred)',
    'hostility':'hostility (hatred)',
    'obstruct':'block',
    'pledge':'pledge(word of honor)',
    'inflicts':'imposes',
    'massacre':'massacre (murder/slaughter of people) ',
    'massacred':'massacred (murder/slaughter of people)',
    'commodities':'assets',
    'debased':'wicked',
    'eminent':'eminent (very important)',
    'defilement':'degradation',
    'insolent':'arrogant',
    'insolently':'arrogantly',
    'prone':'prone (lying flat)',
    'afflict':'suffer',
    'serpent':'snake',
    'bewitched':'bewitched (to affect by witchcraft)',
    'subjugators':'winners',
    'tablets':'tablets (a flat slab, intended to bear writtings)',
    'heedless':'careless',
    'inscription':'inscription (a historical, religious, or other record cut, impressed, painted, or written on stone, brick, metal, or other hard surface)',
    'absolved':'exempt',
    'contrived':'manipulated',
    'equate':'regard',
    'thereform':'from that place',
    'deities':'Gods',
    'intercessor':'mediator',
    'intercessors':'mediators',
    'finality':'finality (the fact of being final)',
    'appraisal':'assessment',
    'prohibited':'forbid',
    'digress':'digress (to turn aside)',
    'tyrannical':'brutal',
    'thereto':'to that',
    'expiation':'expiation (to make amends)',
    'perjury':'perjury (lying under oath)',
    'sanctity':'holiness',
    'substitute':'alternative',
    'devour':'swallow',
    'detriment':'disadvantage',
    'ordains':'establish',
    'ordained':'established',
    'decree':'legal order',
    'decreed':'mandated',
    'chastity':'purity',
    'affliction':'suffering',
    'arbitrator':'arbitrator (settler of a dispute)',
    'reconciliation':'harmony',
    'boastful':'bragging',
    'stinginess':'extreme greed',
    'fabricated':'constructed',
    'far astray':'far away',
    'accommodation':'compromise',
    'admonish':'advise',
    'attainment':'achievement',
    'lofty':'high',
    'disposer':'giver',
    'intercedes':'interfere',
    'emigrate':'emigrate (abandon their homes)',
    'wherein':'in which',
    'acquisitions':'profits',
    'conferred':'awarded',
    'incumbent':'necessary',
    'prostrated':'bowed',
    'slander':'falsehood',
    'recompensed':'repayed',
    'contempt':'disrespect',
    'evasion':'avoidance',
    'his abundance':'his rewards',
    'wavering':'swaying',
    'pardoning':'forgiving',
    'pardoned':'forgiven',
    'discriminate':'differentiate',
    'solemn':'dignified',
    'avert':'turn away',
    'desist':'desist (stop doing something)',
    'disdained':'disrespected',
    'emigrant':'emigrant (one who leaves his own country)',
    'manifest': 'clear',
    'attributable': '[attributable (considered impossible)]',
    'martyrdom': 'martyrdom (killed in the cause of God)',
    'steadfast': 'firm',
    'an immorality': 'a crime',
    'persevere': 'work hard',
    'stationed': 'firm',
    'uninhibited': 'unrestrained',
    'martyred': 'martyred (killed in the cause of God)',
    'distress': 'pain',
    'disputing': 'arguing',
    'refuge': 'place to hide',
    'afflicted': 'depressed',
    'decree determined': 'term appointed',
    'thereby': 'by that',
    'tidings': 'news',
    'reinforce': 'increase',
    'hardships': 'severe suffering',
    'intimates': 'close friends',
    'hasten': 'hurry',
    'prostrating': 'bowing',
    'attain': 'achieve',
    'repent': 'feel remorse',
    'abiding': 'living',
    'their recompense': 'their reward',
    'pious': 'devoted',
    'alter': 'change',
    'oaths': 'promises',
    'falsehood': 'untruthfulness',
    'faction': 'group',
    'inclining': 'favoring',
    'equitable': 'shared',
    'invoke': 'call on',
    'supplicate': 'beg',
    'hereafter': 'life after death',
    'leaper': 'leper (A person affected with leprosy disease)',
    'disputed': 'argued',
    'abstaining': 'abstaining (to hold oneself back voluntarily)',
    'expelled': 'rejected',
    'prudence': 'fear',
    'sovereignty': 'power',
    'assemble': 'gather',
    'deluded': 'fooled',
    'arbitrate': 'achieve settlement',
    'swift': 'very fast',
    'heaped-up': 'stacked',
    'penalty': 'punishment',
    'bestower': 'granter',
    'scribe': 'scribe (the one who makes a written copy professionally)',
    'forbearing': 'tolerant',
    'animosity': 'extreme hatred',
    'deviation' :'change',
    'ridicule': 'make fun of',
    'ordinances': 'law',
    'bequeather': 'will',
    'bequest': 'will',
    'testimony': 'testimony (declaration about truth)',
    'usury': 'lending money at high interest',
    'admonition': 'caution',
    'kursi': 'kursi (Chair)',
    'deity': 'god',
    'kingship': 'nobility',
    'acquainted': 'aware',
    'transgress': 'does wrong',
    'alleviation': 'relief',
    'retribution': 'compensation',
    'prescirbed': 'recommended',
    'dissension': 'disagreement',
    'reprieved': 'relief of blame',
    'exalted': 'praised',
    'all encompassing': 'All-Sufficient',
    'dominion': 'authority',
    'abrogate': 'put an end',
    'bounty': 'gift',
    'enjoins': 'commands',
    'wrath': 'extreme anger',
    'wretched': 'terrible',
    'resurrection': 'resurrection (Awakening from the dead)',
    'aggression': 'attack',
    'evicting': 'throwing out',
    'evict': 'throw out',
    'enjoining': 'commanding',
    'woe': 'suffering',
    'unlettered': 'vulgar',
    'covet': 'wish',
    'concealing': 'hiding',
    'irrigate': 'water',
    'plow': 'dig',
    'median between that': '(it is) between the two conditions',
    'do you take us in ridicule?': 'are you mocking us?',
    'despised': 'I look down upon you',
    'transgressed': 'spread sin',
    'transgressing': 'wrong-doers',
    'gushed':'poured out',
    'aided': 'helped',
    'intercession': 'appeal',
    'suffice': 'be enough',
    'righteousness': 'goodness',
    'discord': 'disharmony',
    'ally': 'protector',
    'deviation': 'change',
     '<end>': ' ',
     'discord': 'disharmony',
     'forsake': 'abandon',
     'sovereign': 'ruler',
     'recompense': 'Judgement',
     'bestowed': 'granted',
     'evoked': 'awaken',
     'astray':'lost',
    'transgressions':'wrong-doings',
    'kindled': 'start',
    'illuminated': 'lit up',
    'dread': 'fear',
    'is encompassing of': 'has surrounded',
    'competent': 'capable',
    'attribute': 'assign',
    'abide': 'live',
    'eternally': 'forever',
    'defiantly': '',
    'covenant': 'agreement',
    'sever': 'to cut off',
    'santify': 'purify',
    'prostrate': 'bow',
    'therein': 'in there',
    'conceal': 'hide',
    'scorching':'very hot',
    'discern':'observe',
    'foliage':'foliage (plant leaves collectively)',
    'enumerate':'list',
    'excretion':'excretion (a process in which metabolic waste is eliminated from an organism)',
    'palatable':'palatable (pleasant to taste)',
    'appease':'make concessions',
    'envelopment':'utmost degree',
    'probed':'examined',
    'censured':'censured (severe criticism)',
    'insolvent':'broke',
    'exultantly':'happily',
    'banished':'expelled',
    'sublimity':'dignity',
    'aversion':'dislike',
    'meridian':'meridian (a great circle of the earth passing through the poles and any given point on the earths surface)',
    'deviance':'deviance (abnormality)',
    'murky':'unclear',
    'scalds':'burns',
    'fatigue':'tiredness',
    'supplement':'option',
    'supplication':'supplication (an act of asking earnestlt or humbly)',
    'adhere':'hold fast',
    'unchaste':'shameless',
    'abstention':'restrain',
    'invocation':'calling',
    'insolence':'arrogance',
    'inevitably':'unavoidably',
    'atrocious':'horrifyingly wicked',
    'slacken':'slacken (become less active)',
    'manna':'manna (the food miraculously supllied to the Israelities in the wilderness)',
    'hastened':'hurried',
    'o':'', #'o (o - used before a name in direct address)',
    'splendor':'beauty',
    'heedlessness':'careless',
    'thereupon':'therefore',
    'convulsion':'earthquake',
    'synagogues':'synagogues (a place of assembly (temple))',
    'monasteries':'monasteries (a building occupied by monks living under religious vows)',
    'tyrannized':'oppressed',
    'servitude':'servitude (the state of being a slave)',
    'outstrip':'overtake',
    'incitements':'incitements (provoking unlawful behaviour)',
    'fornicator':'fornicator (a person who has sex with someone who they are not married to)',
    'chaste':'chaste (to stay away from sexual intercourse)',
    'emancipation':'freedom',
    'compulsion':'compulsion (a very strong desire to do something)',
    'adhering':'adhering (to hold fast)',
    'sparingly':'cautiously',
    'tyrants':'cruel rulers',
    'kindred':'family and tribe',
    'haughtiness':'scronful arrogance',
    'haughty':'scornfully arrogant',
    'amending':'amending(to alter)',
    'amenders':'amenders (those who can alter)',
    'supremacy':'high rank',
    'sanctuary':'sanctuary (a holy place',
    'amply':'plenty',
    'replenished':'refill',
    'trodden':'trodden (walk in a specific way)',
    'adornment':'luxury',
    'enormity':'enormity (extreme scale)',
    'dignitaries':'dignitaries (high rank people)',
    'pliable':'flexible',
    'tamarisk':'tamarisk (flowering plant)',
    'benefactor':'benefactor (a person who gives some form of help to benefit a person)',
    'deluded':'fooled',
    'perish':'die',
    'extinguished':'furnished',
    'adorned':'furnished',
    'obliterated':'destroyed',
    'pelted':'struck',
    'contemptible':'humiliated',
    'scalding':'burning',
    'exertion':'labour',
    'explicit':'clear',
    'begotten':'begotten (brought into existence a child)',
    'lineage':'lineage (direct descent from an ancestor)',
    'depletion':'reduction',
    'purulence':'purulence (dirty wound discharges)',
    'reiterate':'reiterate (to do over repeatedly)',
    'skeptic':'skeptic (an attitude of doubt)',
    'skepticism':'skepticism (an attitude of doubt)',
    'exult':'rejoice',
    'decisive word':'word of judgement',
    'thereof':'of that',
    'enjoined':'urged',
    'thereby':'by that means',
    'subdued':'accomplished',
    'apportioned':'divided',
    'conjunction':'conjunction (state of being conjoined)',
    'denominations':'groups',
    'averse':'averse (feeling of dislike)',
    'transcribed':'transcribed (to make a written copy of)',
    'uff':'uff (an expression of distaste and irritation)',
    'oblivion':'oblivion (lack of consciousness)',
    'vengeance':'revenge',
    'allegiance':'loyalty',
    'imminent':'imminent (ready to take place)',
    'chauvinism':'chauvinism (extreme ignorance)',
    'stalks':'stalks (a part of a plant that supports another)',
    'defiance':'resistance',
    'inscribed':'inscribed (object marked with characters)',
    'parchment':'parchment (material made from animal skin)',
    'soothsayer':'fortune teller',
    'deterrence':'deterrrence (to prevent someone from doing something)',
    'sheaths':'enclosing',
    'brocade':'brocade (a rich fabric woven with a raised pattern, typically with gold or silver thread)',
    'pavilions':'in very large tents',
    'affluence':'wealth',
    'fortified':'armed',
    'propped':'leaned',
    'lodge them':'lodge them (let the women live (in iddat)',
    'dwell':'live',
    'retain':'keep',
    'dissolution':'formal release from guilt',
    'alienation':'isolation',
    'aloft':'up',
    'snout':'nose',
    'infirm':'weak',
    'cubits':'cubits (ancient measurement of length)',
    'aorta':'aorta (the main artery of the blood, supplying oxygenated blood to the circulatory system)',
    'supplicant':'supplicant (someone who prays to God)',
    'vainly':'unsuccessfully',
    'ascent':'rising upward',
    'grandeur':'glory',
    'arduous':'severe',
    'respite':'delay',
    'convulse':'shake violently',
    'scowled':'scowled (to contract the brow in an expression of displeasure)',
    'permanence':'permanence (the quality of being permanent)',
    'contorted':'deformed',
    'swaggering':'swaggering (overbearing self-connfidence)',
    'mirage':'mirage (an image, produced by very hot air, of something that seems to be far away but does not really exist)',
    'entwined':'thick',
    'pasture':'grass',
    'torrents':'sudden large amount',
    'herbage':'nutricious plants',
    'shrubbery':'group of shrubs',
    'derisive':'mocking',
    'jesting':'joking',
    'musk':'fragrance',
    'trench':'ditch',
    'slate':'rock',
    'stubble':'rotten rubbish',
    'resurrected':'resurrected (Awakened from the dead)',
    'discernment':'judgement',
    'polytheists':'polytheists (belief in many Gods)',
    'abyss':'bottomless pit'

}

def dictionary1(word):
    list=['abyss','polytheists','derisive','reprieved','resurrected','leper','discernment','unto','stubble','trench','slate','musk','o','jesting','torrents','herbage','shrubbery','pasture','mirage','entwined','permanence','contorted','swaggering','scowled','respite','convulse','arduous','grandeur','supplicant','ascent','vainly','infirm','cubits','aorta','snout','alienation','aloft','dissolution','lodge','retain','dwell','propped','fortified','affluence','sheaths','brocade','pavilions','deterrence','defiance','allegiance','imminent','chauvinism','offshoots','stalks','vengeance','oblivion','Uff','transcribed','thereby','subdued','apportioned','conjunction','denominations','averse','enjoined','thereof','decisive word','skeptic','skepticism','shackle','shackles','reiteration','depletion','purulence','pelted','contemptible','scalding','exertion','explicit','begotten','lineage','extinguished','adorned','obliterated','deluded','perish','tamarisk','benefactor','pliable','insolently','trodden','adornment','enormity','dignitaries','massacred','amply','replenished','countenance','intercessors','haughtiness','haughty','sanctuary','amending','amenders','supremacy','tyrant','kindred','adhering','sparingly','compulsion','emancipation','chaste','fornicator','servitude','outstrip','incitements','convulsion','synagogues','monasteries','tyrannized','heedlessness','thereupon','slacken','manna','hastened','splendor','supplication','adhere','unchaste','abstention','invocation','insolence','inevitably','atrocious','probed','censured','insolvent','exultantly','banished','sublimity','aversion','meridian','deviance','murky','scalds','fatigue','supplement','foliage','enumerate','excretion','palatable','envelopment','appease','scorching','discern','deviant','cessation','calamity','repelling','conspicuous','merchandise','impassioned','coercion','despaired','adversity','impending','undiminished','bestowal','availed','apprehension','shriek','hamstrung','disquieting','tyrant','obstinate','forelock','disembark','anchorage','depositories','adorments','exultant','tyranny','enmity','ambush','besiege','kinship','striven','commerce','flanks','tranquility','apprehensive','vanities','stingy','bedouins','invocations','afflicted','inflictions','wherein','therewith','hostilities','hostility','obstruct','pledge','inflicts','massacre','commodities','debased','eminent','defilement','insolent','prone','afflict','serpent','bewitched','subjugators','tablets','heedless','inscription','absolved','contrived','equate','thereform','deities','intercessor','finality','appraisal','prohibited', 'digress','tyrannical','thereto','expiation','perjury','sanctity','substitute','devour','detriment','ordains','ordained','decree','decreed','chastity','affliction','arbitrator','reconciliation','boastful','stinginess','fabricated','far astray','accommodation','admonish','attainment','lofty','disposer','intercedes', 'emigrate', 'wherein', 'acquisitions', 'conferred','incumbent', 'prostrated','slander','recompensed','contempt','evasion','his abundance','wavering','pardoning','pardoned','discriminate','solemn','avert','desist','disdained','emigrant','sovereign','recompense','bestowed','evoked','astray','transgressions','kindled','illuminated','dread','encompassing','competent','attribute','abide','eternally','defiantly','covenant','sever','sanctify','prostrate','therein','conceal','righteousness','suffice','intercession','aided','gushed','transgressions','transgressed','despised','ridicule','median','plow','irrigate','concealing','covet','unlettered','woe','enjoining','evict','evicting','aggression','resurrection','wretched','wrath','enjoins','bounty','abrogate','dominion','all encompassing','exalted','dissension','prescribed','retribution','alleviation','transgresses','acquainted','kingship','deity','kursi','admonition','usury','testimony','bequest','bequeather','ordinances','deviation','animosity','forbearing','scribe','discord','bestower','penalty','heaped-up','swift','arbitrate','deluded','assemble','sovereignty','prudence','expelled','abstaining','disputed','leaper','hereafter','supplicate','invoke','equitable','inclining','faction','falsehood','oaths','alter','pious','abiding','repent','attain','prostrating','hasten','ally','intimates','hardship','ally','reinforce','tidings','thereby','decree','afflicted','refuge','disputing','distress','martyred','uninhibited','stationed','persevere','immorality','steadfast','martyrdom','forsake','attributable','booty','manifest']
    if word in list:
       a=word
       return a

def dictionary2(word):
    list=['abyss','polytheists','derisive','reprieved','resurrected','leper','discernment','unto','stubble','trench','slate','musk','o','jesting','torrents','herbage','shrubbery','pasture','mirage','entwined','permanence','contorted','swaggering','scowled','respite','convulse','arduous','grandeur','supplicant','ascent','vainly','infirm','cubits','aorta','snout','alienation','aloft','dissolution','lodge','retain','dwell','propped','fortified','affluence','sheaths','brocade','pavilions','deterrence','defiance','allegiance','imminent','chauvinism','offshoots','stalks','vengeance','oblivion','Uff','transcribed','thereby','subdued','apportioned','conjunction','denominations','averse','enjoined','thereof','decisive word','skeptic','skepticism','shackle','shackles','reiteration','depletion','purulence','pelted','contemptible','scalding','exertion','explicit','begotten','lineage','extinguished','adorned','obliterated','deluded','perish','tamarisk','benefactor','pliable','insolently','trodden','adornment','enormity','dignitaries','massacred','amply','replenished','countenance','intercessors','haughtiness','haughty','sanctuary','amending','amenders','supremacy','tyrant','kindred','adhering','sparingly','compulsion','emancipation','chaste','fornicator','servitude','outstrip','incitements','convulsion','synagogues','monasteries','tyrannized','heedlessness','thereupon','slacken','manna','hastened','splendor','supplication','adhere','unchaste','abstention','invocation','insolence','inevitably','atrocious','probed','censured','insolvent','exultantly','banished','sublimity','aversion','meridian','deviance','murky','scalds','fatigue','supplement','foliage','enumerate','excretion','palatable','envelopment','appease','scorching','discern','deviant','cessation','calamity','repelling','conspicuous','merchandise','impassioned','coercion','despaired','adversity','impending','undiminished','bestowal','availed','apprehension','shriek','hamstrung','disquieting','tyrant','obstinate','forelock','disembark','anchorage','depositories','adorments','exultant','tyranny','enmity','ambush','besiege','kinship','striven','commerce','flanks','tranquility','apprehensive','vanities','stingy','bedouins','invocations','afflicted','inflictions','wherein','therewith','hostilities','hostility','obstruct','pledge','inflicts','massacre','commodities','debased','eminent','defilement','insolent','prone','afflict','serpent','bewitched','subjugators','tablets','heedless','inscription','absolved','contrived','equate','thereform','deities','intercessor','finality','appraisal','prohibited', 'digress','tyrannical','thereto','expiation','perjury','sanctity','substitute','devour','detriment','ordains','ordained','decree','decreed','chastity','affliction','arbitrator','reconciliation','boastful','stinginess','fabricated','far astray','accommodation','admonish','attainment','lofty','disposer','intercedes', 'emigrate', 'wherein', 'acquisitions', 'conferred','incumbent', 'prostrated','slander','recompensed','contempt','evasion','his abundance','wavering','pardoning','pardoned','discriminate','solemn','avert','desist','disdained','emigrant','sovereign','recompense','bestowed','evoked','astray','transgressions','kindled','illuminated','dread','encompassing','competent','attribute','abide','eternally','defiantly','covenant','sever','sanctify','prostrate','therein','conceal','righteousness','suffice','intercession','aided','gushed','transgressions','transgressed','despised','ridicule','median','plow','irrigate','concealing','covet','unlettered','woe','enjoining','evict','evicting','aggression','resurrection','wretched','wrath','enjoins','bounty','abrogate','dominion','all encompassing','exalted','dissension','prescribed','retribution','alleviation','transgresses','acquainted','kingship','deity','kursi','admonition','usury','testimony','bequest','bequeather','ordinances','deviation','animosity','forbearing','scribe','discord','bestower','penalty','heaped-up','swift','arbitrate','deluded','assemble','sovereignty','prudence','expelled','abstaining','disputed','leaper','hereafter','supplicate','invoke','equitable','inclining','faction','falsehood','oaths','alter','pious','abiding','repent','attain','prostrating','hasten','ally','intimates','hardship','ally','reinforce','tidings','thereby','decree','afflicted','refuge','disputing','distress','martyred','uninhibited','stationed','persevere','immorality','steadfast','martyrdom','forsake','attributable','booty','manifest']
    if word in list:
       print('Complex/Archaic Word:',word)

for i in range(3742):
  
  print("Archaic Translation:",seq2text(X_test[i]))
  print("Expected Universal Translation:",seq2summary(y_test[i]))
  print("Predicted Universal Translation:",decode_sequence(X_test[i].reshape(1,291)).lstrip())
  x=decode_sequence(X_test[i].reshape(1,291)).lstrip()
  x1=x.split()
  for a in range(len(x1)): 
    dictionary2(x1[a]) 

  B1=str(decode_sequence(X_test[i].reshape(1,291)).lstrip())
  B2=str(seq2summary(y_test[i]))
  C1=B1
  C2=B2
  q=decode_sequence(X_test[i].reshape(1,291)).lstrip()
  s = SequenceMatcher(None, C1,C2)

 
  regex = re.compile(r'\b(' + '|'.join(map(re.escape, dct.keys())) + r')\b')
  #print("Text Style Transfer Translation:",regex.sub(lambda match: dct[match.group(0)], q))


  new_text = x
  x2=new_text.split()
  for a in range(len(x1)): 
    complete_cwi_predictions = dictionary1(x2[a])
    #print(complete_cwi_predictions)
    bert_candidates =   get_bert_candidates(x, complete_cwi_predictions)
    for word_to_replace, l_candidates in bert_candidates:
     tuples_word_zipf = []
     for w in l_candidates:
       if w.isalpha():
         tuples_word_zipf.append((w, zipf_frequency(w, 'en')))
     tuples_word_zipf = sorted(tuples_word_zipf, key = lambda x: x[1], reverse=True)
     
     success=False
     while not success:
       try:
        new_text = re.sub(word_to_replace, tuples_word_zipf[0][0], new_text)
        success=True
       except:
        break
        

  
  print("Text Style Transfer Text :", new_text, "\n")
  a = set(C1.split())
  b = set(regex.sub(lambda match: dct[match.group(0)], q).split())
  jj=str(regex.sub(lambda match: dct[match.group(0)], q))
  similarity1 = float(len(a.intersection(new_text.split()))*1.0/len(a.union(new_text.split())))
  document=[B1,new_text]

  
  print('BLEUscore:',bleu([C1], C2, smoothing_function=smoothie))
  print('SequenceMatcher:',s.ratio())
  print('Jaro Distance:',jellyfish.jaro_similarity(C1, C2))
  print('Match Rating Approach Comparison:',jellyfish.match_rating_comparison(C1, C2))
  print('Hamming Distance:',textdistance.hamming.normalized_similarity(C1,C2))
  print('Normalized Levenshtein:',normalized_levenshtein.similarity(C1, C2))
  print('Jaccard Similarity',similarity1)
  vectorizer = TfidfVectorizer()
  trsfm=vectorizer.fit_transform(document)
 
  print('Cosine Similarity:',cosine_similarity(trsfm[0], trsfm[1]))
  pd.DataFrame(trsfm.toarray(),columns=vectorizer.get_feature_names(),index=['Predicted Universal Translation','Text Style Transfer Translation'])
  print(i)
  print("\n")

  
  sum=sum+bleu([C1], C2, smoothing_function=smoothie)
  sum1=sum1+s.ratio()
  sum2=sum2+jellyfish.jaro_similarity(C1, C2)
  sum3=sum3+jellyfish.match_rating_comparison(C1, C2)
  sum4=sum4+textdistance.hamming.normalized_similarity(C1,C2)
  sum5=sum5+similarity1
  sum6=sum6+normalized_levenshtein.similarity(C1, C2)
  sum7=sum7+cosine_similarity(trsfm[0], trsfm[1])


performance=sum/3742
performance1=sum1/3742
performance2=sum2/3742
performance3=sum3/3742
performance4=sum4/3742
performance5=sum5/3742
performance6=sum6/3742
performance7=sum7/3742
print('Syntactic Analysis')
print('BLEUscore Performance:',performance*100,'%')
print('SequenceMatcher Performance:',performance1*100,'%')
print('Jaro Similarity Performance:',performance2*100,'%')
print('Match Rating Comparison Performance:',performance3*100,'%')
print('Hamming Distance Performance:',performance4*100,'%')
print('Normalized Levenshtein Performance:',performance6*100,'%')
print('Semantic Analysis')
print('Jaccard Similarity Performance:',performance5*100,'%')
print('Cosine Similarity Performance:',performance7*100,'%')
# Out:
# Streaming output truncated to the last 5000 lines.
# Normalized Levenshtein: 0.24305555555555558
# Jaccard Similarity 0.8333333333333334
# Cosine Similarity: [[0.88010365]]
# 3443
#
#
# Archaic Translation: god blots out and he establishes whatsoever he will and with him is the essence of the book
# Expected Universal Translation: allah eliminates what he wills or confirms and with him is the mother of the book
# Predicted Universal Translation: allah eliminates what he wills or confirms and with him is the mother of the book
# Text Style Transfer Text : allah eliminates what he wills or confirms and with him is the mother of the book
#
# BLEUscore: 0.9875752277151817
# SequenceMatcher: 0.9938650306748467
# Jaro Distance: 0.9959349593495935
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9878048780487805
# Normalized Levenshtein: 0.9878048780487805
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3444
#
#
# Archaic Translation: god knows well your enemies god suffices as a protector god suffices as a helper
# Expected Universal Translation: and allah is most knowing of your enemies and sufficient is allah as an ally and sufficient is allah as a helper
# Predicted Universal Translation: but allah knows what is declared of speech and he knows what you conceal
# Complex/Archaic Word: conceal
# Text Style Transfer Text : but allah knows what is declared of speech and he knows what you conceal
#
# BLEUscore: 0.24361865460731616
# SequenceMatcher: 0.33513513513513515
# Jaro Distance: 0.6473472473329739
# Match Rating Approach Comparison: False
# Hamming Distance: 0.07079646017699115
# Normalized Levenshtein: 0.2920353982300885
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3445
#
#
# Archaic Translation: to thee we sent the scripture in truth confirming the scripture that came before it and guarding it in safety so judge between them by what allah hath revealed and follow not their vain desires diverging from the truth that hath come to thee to each among you have we prescribed a law and an open way if allah had so willed he would have made you a single people but his plan is to test you in what he hath given you so strive as in a race in all virtues the goal of you all is to allah it is he that will show you the truth of the matters in which ye dispute
# Expected Universal Translation: and we have revealed to you o muúammad the book in truth confirming that which preceded it of the scripture and as a criterion over it so judge between them by what allah has revealed and do not follow their inclinations away from what has come to you of the truth to each of you we prescribed a law and a method had allah willed he would have made you one nation united in religion but he intended to test you in what he has given you so race to all that is good to allah is your return all together and he will then inform you concerning that over which you used to differ
# Predicted Universal Translation: and we have revealed to the people of the book of yourselves when you came to them in the signs of allah and you would not find for themselves besides allah any protector or any helper
# Text Style Transfer Text : and we have revealed to the people of the book of yourselves when you came to them in the signs of allah and you would not find for themselves besides allah any protector or any helper
#
# BLEUscore: 0.2185192798956277
# SequenceMatcher: 0.0922266139657444
# Jaro Distance: 0.6489019561257623
# Match Rating Approach Comparison: True
# Hamming Distance: 0.05739130434782613
# Normalized Levenshtein: 0.2486956521739131
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3446
#
#
# Archaic Translation: iblis satan said by your might then i will surely mislead them all
# Expected Universal Translation: iblees said by your might i will surely mislead them all
# Predicted Universal Translation: iblees said do you see this one whom you have honored above me if you delay me until the day of resurrection i will surely destroy his descendants except for a few
# Complex/Archaic Word: resurrection
# Text Style Transfer Text : iblees said do you see this one whom you have honored above me if you delay me until the day of death i will surely destroy his descendants except for a few
#
# BLEUscore: 0.09801313408720756
# SequenceMatcher: 0.39090909090909093
# Jaro Distance: 0.6522936827102148
# Match Rating Approach Comparison: True
# Hamming Distance: 0.11042944785276076
# Normalized Levenshtein: 0.28220858895705525
# Jaccard Similarity 0.9333333333333333
# Cosine Similarity: [[0.9493184]]
# 3447
#
#
# Archaic Translation: it is to free a slave
# Expected Universal Translation: it is the freeing of a slave
# Predicted Universal Translation: indeed it is guidance and near
# Text Style Transfer Text : indeed it is guidance and near
#
# BLEUscore: 0.2366439369946226
# SequenceMatcher: 0.3728813559322034
# Jaro Distance: 0.6291187739463601
# Match Rating Approach Comparison: False
# Hamming Distance: 0.09999999999999998
# Normalized Levenshtein: 0.16666666666666663
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3448
#
#
# Archaic Translation: men whom neither merchandise nor sale beguileth from remembrance of allah and constancy in prayer and paying to the poor their due who fear a day when hearts and will be overturned
# Expected Universal Translation: are men whom neither commerce nor sale distracts from the remembrance of allah and performance of prayer and giving of zakah they fear a day in which the hearts and eyes will fearfully turn about
# Predicted Universal Translation: are men whom neither commerce nor sale distracts from the remembrance of allah and performance of prayer and giving of zakah they fear a day in which the hearts and eyes will fearfully turn about
# Complex/Archaic Word: commerce
# Text Style Transfer Text : are men whom neither money nor sale distracts from the remembrance of allah and performance of prayer and giving of zakah they fear a day in which the hearts and eyes will fearfully turn about
#
# BLEUscore: 0.9948584414934554
# SequenceMatcher: 0.9974424552429667
# Jaro Distance: 0.9982993197278912
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9948979591836735
# Normalized Levenshtein: 0.9948979591836735
# Jaccard Similarity 0.9354838709677419
# Cosine Similarity: [[0.95966679]]
# 3449
#
#
# Archaic Translation: and there comes not to them a communication of the communications of their lord but they turn aside from it
# Expected Universal Translation: and no sign comes to them from the signs of their lord except that they are from it turning away
# Predicted Universal Translation: and no sign comes to them from the signs of their lord except that they turn away therefrom
# Text Style Transfer Text : and no sign comes to them from the signs of their lord except that they turn away therefrom
#
# BLEUscore: 0.8543106203039975
# SequenceMatcher: 0.8723404255319149
# Jaro Distance: 0.9389653552748652
# Match Rating Approach Comparison: True
# Hamming Distance: 0.7525773195876289
# Normalized Levenshtein: 0.7835051546391752
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3450
#
#
# Archaic Translation: he said my lord verily i fear that they will belie me
# Expected Universal Translation: he said my lord indeed i fear that they will deny me
# Predicted Universal Translation: he said my lord indeed i fear that they will deny me
# Text Style Transfer Text : he said my lord indeed i fear that they will deny me
#
# BLEUscore: 0.9805732749982651
# SequenceMatcher: 0.9904761904761905
# Jaro Distance: 0.9937106918238993
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9811320754716981
# Normalized Levenshtein: 0.9811320754716981
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3451
#
#
# Archaic Translation: of the two pairs of camels and cows are the males unlawful to eat or the females or that which exists in the wombs of the females were you present when god commanded you to do this who are more unjust than those who ascribe falsehood to god and out of ignorance make others go astray god does not guide the unjust
# Expected Universal Translation: and of the camels two and of the cattle two say is it the two males he has forbidden or the two females or that which the wombs of the two females contain or were you witnesses when allah charged you with this then who is more unjust than one who invents a lie about allah to mislead the people by something other than knowledge indeed allah does not guide the wrongdoing people
# Predicted Universal Translation: said the eminent among the people of pharaoh indeed this is a learned magician
# Complex/Archaic Word: eminent
# Text Style Transfer Text : said the great among the people of pharaoh indeed this is a learned magician
#
# BLEUscore: 0.12618117967230671
# SequenceMatcher: 0.061269146608315096
# Jaro Distance: 0.5569985451251942
# Match Rating Approach Comparison: False
# Hamming Distance: 0.01055408970976257
# Normalized Levenshtein: 0.16094986807387868
# Jaccard Similarity 0.8571428571428571
# Cosine Similarity: [[0.8763511]]
# 3452
#
#
# Archaic Translation: allah has promised the hypocrites men and women and the disbelievers the fire of hell therein shall they abide it will suffice them allah has cursed them and for them is the lasting torment
# Expected Universal Translation: allah has promised the hypocrite men and hypocrite women and the disbelievers the fire of hell wherein they will abide eternally it is sufficient for them and allah has cursed them and for them is an enduring punishment
# Predicted Universal Translation: allah has promised the hypocrite men and hypocrite women and the disbelievers the fire of hell wherein they will abide eternally it is sufficient for them and allah has cursed them and for them is an enduring punishment
# Complex/Archaic Word: wherein
# Complex/Archaic Word: abide
# Complex/Archaic Word: eternally
# Text Style Transfer Text : allah has promised the hypocrite men and hypocrite women and the disbelievers the fire of hell and they will live and it is sufficient for them and allah has cursed them and for them is an enduring punishment
#
# BLEUscore: 0.9954232208531829
# SequenceMatcher: 0.9977220956719818
# Jaro Distance: 0.9984848484848485
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9954545454545455
# Normalized Levenshtein: 0.9954545454545455
# Jaccard Similarity 0.8518518518518519
# Cosine Similarity: [[0.93263699]]
# 3453
#
#
# Archaic Translation: thereafter after them we produced another generation
# Expected Universal Translation: then we produced after them a generation of others
# Predicted Universal Translation: then we produced after them a generation of others
# Text Style Transfer Text : then we produced after them a generation of others
#
# BLEUscore: 0.9797875586021995
# SequenceMatcher: 0.9900990099009901
# Jaro Distance: 0.9934640522875817
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9803921568627451
# Normalized Levenshtein: 0.9803921568627451
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3454
#
#
# Archaic Translation: so travel with thy household in a portion of the night and follow thou their backs let none of you turn round but go whither ye are commanded
# Expected Universal Translation: so set out with your family during a portion of the night and follow behind them and let not anyone among you look back and continue on to where you are commanded
# Predicted Universal Translation: so set out with your family during a portion of the night and follow behind them and let not anyone among you look back and continue on to where you are commanded
# Text Style Transfer Text : so set out with your family during a portion of the night and follow behind them and let not anyone among you look back and continue on to where you are commanded
#
# BLEUscore: 0.9938077518364797
# SequenceMatcher: 0.9969230769230769
# Jaro Distance: 0.9979550102249489
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9938650306748467
# Normalized Levenshtein: 0.9938650306748467
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3455
#
#
# Archaic Translation: it may be that my lord will give me something better than your garden and will send on it torment bolt etc from the sky then it will be a slippery earth
# Expected Universal Translation: it may be that my lord will give me something better than your garden and will send upon it a calamity from the sky and it will become a smooth dusty ground
# Predicted Universal Translation: it may be that my lord will give me something better than your garden and will send upon it a calamity from the sky and it will become a smooth dusty ground
# Complex/Archaic Word: calamity
# Text Style Transfer Text : it may be that my lord will give me something better than your garden and will send upon it a light from the sky and it will become a smooth dusty ground
#
# BLEUscore: 0.9935687982842645
# SequenceMatcher: 0.9968051118210862
# Jaro Distance: 0.9978768577494691
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9936305732484076
# Normalized Levenshtein: 0.9936305732484076
# Jaccard Similarity 0.9259259259259259
# Cosine Similarity: [[0.95607965]]
# 3456
#
#
# Archaic Translation: allah ordained this only as a message of good cheer for you and that thereby your hearts might be at rest victory cometh only from allah the mighty the wise
# Expected Universal Translation: and allah made it not except as a sign of good tidings for you and to reassure your hearts thereby and victory is not except from allah the exalted in might the wise
# Predicted Universal Translation: and allah is most knowing of what you do
# Text Style Transfer Text : and allah is most knowing of what you do
#
# BLEUscore: 0.12531675367360823
# SequenceMatcher: 0.2621359223300971
# Jaro Distance: 0.6078557473135786
# Match Rating Approach Comparison: True
# Hamming Distance: 0.09036144578313254
# Normalized Levenshtein: 0.19277108433734935
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3457
#
#
# Archaic Translation: if there had been in them any gods except allah they would both have certainly been in a state of disorder therefore glory be to allah the lord of the dominion above what they attribute to him
# Expected Universal Translation: had there been within the heavens and earth gods besides allah they both would have been ruined so exalted is allah lord of the throne above what they describe
# Predicted Universal Translation: had there been within them the earth gods from their gods which they had been with it humbled and said leave us our god and the word of jacob took for a time
# Text Style Transfer Text : had there been within them the earth gods from their gods which they had been with it humbled and said leave us our god and the word of jacob took for a time
#
# BLEUscore: 0.508904805356926
# SequenceMatcher: 0.5488958990536278
# Jaro Distance: 0.7800126311000432
# Match Rating Approach Comparison: True
# Hamming Distance: 0.22499999999999998
# Normalized Levenshtein: 0.40625
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3458
#
#
# Archaic Translation: our lord verily it is you who will gather mankind together on the day about which there is no doubt verily allah never breaks his promise
# Expected Universal Translation: our lord surely you will gather the people for a day about which there is no doubt indeed allah does not fail in his promise
# Predicted Universal Translation: our lord surely you will gather the people for a day about which there is no doubt indeed allah does not fail in his promise
# Text Style Transfer Text : our lord surely you will gather the people for a day about which there is no doubt indeed allah does not fail in his promise
#
# BLEUscore: 0.9919021676052067
# SequenceMatcher: 0.9959839357429718
# Jaro Distance: 0.9973333333333333
# Match Rating Approach Comparison: True
# Hamming Distance: 0.992
# Normalized Levenshtein: 0.992
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3459
#
#
# Archaic Translation: your lord will issue his decree about their believers and disbelievers differences on the day of judgment
# Expected Universal Translation: indeed your lord will judge between them on the day of resurrection concerning that over which they used to differ
# Predicted Universal Translation: and your lord is going to give them
# Text Style Transfer Text : and your lord is going to give them
#
# BLEUscore: 0.1876281020215307
# SequenceMatcher: 0.38666666666666666
# Jaro Distance: 0.6018570801179496
# Match Rating Approach Comparison: True
# Hamming Distance: 0.04347826086956519
# Normalized Levenshtein: 0.25217391304347825
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3460
#
#
# Archaic Translation: had they gone forth among you they would only have increased you in trouble and run to and fro in your midst seeking to stir up sedition between you and some of you would listen to them and god knows the evildoers
# Expected Universal Translation: had they gone forth with you they would not have increased you except in confusion and they would have been active among you seeking to cause you fitnah and among you are avid listeners to them and allah is knowing of the wrongdoers
# Predicted Universal Translation: had they gone forth with you they would not have increased you except in confusion and they would have been active among you seeking to cause you fitnah and among you are avid listeners to them and allah is knowing of the wrongdoers
# Text Style Transfer Text : had they gone forth with you they would not have increased you except in confusion and they would have been active among you seeking to cause you fitnah and among you are avid listeners to them and allah is knowing of the wrongdoers
#
# BLEUscore: 0.99568024459715
# SequenceMatcher: 0.9978494623655914
# Jaro Distance: 0.9985693848354793
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9957081545064378
# Normalized Levenshtein: 0.9957081545064378
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3461
#
#
# Archaic Translation: have they not observed what is before them and what is behind them of the sky and the earth if we will we can make the earth swallow them or cause from the sky to fall on them lo herein surely is a portent for every slave who turneth to allah repentant
# Expected Universal Translation: then do they not look at what is before them and what is behind them of the heaven and earth if we should will we could cause the earth to swallow them or could let fall upon them fragments from the sky indeed in that is a sign for every servant turning back to allah
# Predicted Universal Translation: then do they not look at what is before them and what is behind them of the heaven and earth if we should will we could cause the earth to swallow them or could let fall upon them fragments from the sky indeed in that is a sign for every servant turning back to allah
# Text Style Transfer Text : then do they not look at what is before them and what is behind them of the heaven and earth if we should will we could cause the earth to swallow them or could let fall upon them fragments from the sky indeed in that is a sign for every servant turning back to allah
#
# BLEUscore: 0.9962475886162333
# SequenceMatcher: 0.9981308411214953
# Jaro Distance: 0.9987562189054726
# Match Rating Approach Comparison: True
# Hamming Distance: 0.996268656716418
# Normalized Levenshtein: 0.996268656716418
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3462
#
#
# Archaic Translation: when moses came to them with our miracles they said these are only invented magic we have never heard of such things from our fathers
# Expected Universal Translation: but when moses came to them with our signs as clear evidences they said this is not except invented magic and we have not heard of this religion among our forefathers
# Predicted Universal Translation: but when moses came to them with our signs as clear evidences they said this is not except invented magic and we have not heard of this religion among our forefathers
# Text Style Transfer Text : but when moses came to them with our signs as clear evidences they said this is not except invented magic and we have not heard of this religion among our forefathers
#
# BLEUscore: 0.9939574273182392
# SequenceMatcher: 0.996996996996997
# Jaro Distance: 0.9980039920159681
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9940119760479041
# Normalized Levenshtein: 0.9940119760479041
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3463
#
#
# Archaic Translation: lo he used not to believe in allah the tremendous
# Expected Universal Translation: indeed he did not used to believe in allah the most great
# Predicted Universal Translation: indeed he did not used to believe in allah the most great
# Text Style Transfer Text : indeed he did not used to believe in allah the most great
#
# BLEUscore: 0.9822938874664828
# SequenceMatcher: 0.991304347826087
# Jaro Distance: 0.9942528735632185
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9827586206896551
# Normalized Levenshtein: 0.9827586206896551
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3464
#
#
# Archaic Translation: those who disbelieve in the oneness of allah and in the message of prophet muhammad saw and hinder men from the path of allah islamic monotheism he will render their deeds vain
# Expected Universal Translation: those who disbelieve and avert people from the way of allah he will waste their deeds
# Predicted Universal Translation: those who disbelieve and avert people from the way of allah he will waste their deeds
# Complex/Archaic Word: avert
# Text Style Transfer Text : those who disbelieve and keep people from the way of allah he will waste their deeds
#
# BLEUscore: 0.9881635957019257
# SequenceMatcher: 0.9941520467836257
# Jaro Distance: 0.9961240310077519
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9883720930232558
# Normalized Levenshtein: 0.9883720930232558
# Jaccard Similarity 0.8823529411764706
# Cosine Similarity: [[0.88363514]]
# 3465
#
#
# Archaic Translation: and of them is he who looketh toward thee but canst thou guide the blind even though they see not
# Expected Universal Translation: and among them are those who look at you but can you guide the blind although they will not attempt to see
# Predicted Universal Translation: and of them are those who do not believe but they have disbelieved in allah and his messenger and then doubt not that the truth do not used to believe
# Text Style Transfer Text : and of them are those who do not believe but they have disbelieved in allah and his messenger and then doubt not that the truth do not used to believe
#
# BLEUscore: 0.32769194838417354
# SequenceMatcher: 0.45136186770428016
# Jaro Distance: 0.7239218079241203
# Match Rating Approach Comparison: True
# Hamming Distance: 0.09333333333333338
# Normalized Levenshtein: 0.4066666666666666
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3466
#
#
# Archaic Translation: what plea have they that allah should not punish them when they debar his servants from the inviolable place of worship though they are not its fitting guardians its fitting guardians are those only who keep their duty to allah but most of them know not
# Expected Universal Translation: but why should allah not punish them while they obstruct people from almasjid al îaram and they were not fit to be its guardians its true guardians are not but the righteous but most of them do not know
# Predicted Universal Translation: and whatever allah grants to people of mercy from him to which he has created shadows and has prepared for them a punishment from the punishment who is farthest astray
# Complex/Archaic Word: astray
# Text Style Transfer Text : and whatever allah grants to people of mercy from him to which he has created shadows and has prepared for them a punishment from the punishment who is farthest astray
#
# BLEUscore: 0.32689628310735547
# SequenceMatcher: 0.032432432432432434
# Jaro Distance: 0.725513762371775
# Match Rating Approach Comparison: False
# Hamming Distance: 0.06896551724137934
# Normalized Levenshtein: 0.3152709359605911
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3467
#
#
# Archaic Translation: is this not a better reward than the tree of zaqqum
# Expected Universal Translation: is paradise a better accommodation or the tree of zaqqum
# Predicted Universal Translation: is it not true that every time they took a covenant a party of them threw it away but in fact most of them do not believe
# Complex/Archaic Word: covenant
# Text Style Transfer Text : is it not true that every time they took a risk a party of them threw it away but in fact most of them do not believe
#
# BLEUscore: 0.08874503010910217
# SequenceMatcher: 0.2696629213483146
# Jaro Distance: 0.6120121239738464
# Match Rating Approach Comparison: True
# Hamming Distance: 0.024793388429752095
# Normalized Levenshtein: 0.2644628099173554
# Jaccard Similarity 0.9130434782608695
# Cosine Similarity: [[0.94185981]]
# 3468
#
#
# Archaic Translation: and be moderate or show no insolence in your walking and lower your voice verily the harshest of all voices is the voice braying of the ass
# Expected Universal Translation: and be moderate in your pace and lower your voice indeed the most disagreeable of sounds is the voice of donkeys
# Predicted Universal Translation: and be not haughty with allah indeed the wrongdoers have been made attractive so they follow their own desires and who is more astray than one who follows his desire without guidance from allah indeed allah does not guide the defiantly disobedient people
# Complex/Archaic Word: haughty
# Complex/Archaic Word: astray
# Complex/Archaic Word: defiantly
# Text Style Transfer Text : and be not angry with allah indeed the wrongdoers have been made attractive so they follow their own desires and who is more so than one who follows his desire without guidance from allah indeed allah does not guide the deeply disobedient people
#
# BLEUscore: 0.11963509692926394
# SequenceMatcher: 0.2724795640326976
# Jaro Distance: 0.6633553011361929
# Match Rating Approach Comparison: True
# Hamming Distance: 0.06299212598425197
# Normalized Levenshtein: 0.26771653543307083
# Jaccard Similarity 0.868421052631579
# Cosine Similarity: [[0.91293151]]
# 3469
#
#
# Archaic Translation: so he shall be in a life wellpleasing
# Expected Universal Translation: so he will be in a pleasant life
# Predicted Universal Translation: so he will be in a pleasant life
# Text Style Transfer Text : so he will be in a pleasant life
#
# BLEUscore: 0.9682132340352987
# SequenceMatcher: 0.9846153846153847
# Jaro Distance: 0.98989898989899
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9696969696969697
# Normalized Levenshtein: 0.9696969696969697
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3470
#
#
# Archaic Translation: god bears witness that there is no god but he and the angels and men possessed of knowledge justice there is no god but he the allmighty the allwise
# Expected Universal Translation: allah witnesses that there is no deity except him and so do the angels and those of knowledge that he is maintaining creation in justice there is no deity except him the exalted in might the wise
# Predicted Universal Translation: allah witnesses that there is no deity except him and so do the angels and those of knowledge that he is maintaining creation in justice there is no deity except him the exalted in might the wise
# Complex/Archaic Word: deity
# Complex/Archaic Word: deity
# Complex/Archaic Word: exalted
# Text Style Transfer Text : allah witnesses that there is no man except him and so do the angels and those of knowledge that he is maintaining creation in justice there is no man except him the just in might the wise
#
# BLEUscore: 0.9948584414934554
# SequenceMatcher: 0.9974424552429667
# Jaro Distance: 0.9982993197278912
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9948979591836735
# Normalized Levenshtein: 0.9948979591836735
# Jaccard Similarity 0.8518518518518519
# Cosine Similarity: [[0.8586558]]
# 3471
#
#
# Archaic Translation: remember he covered you with a sort of to give you calm as from himself and he caused rain to descend on you from heaven to clean you therewith to remove from you the stain of satan to strengthen your hearts and to plant your feet firmly therewith
# Expected Universal Translation: remember when he overwhelmed you with drowsiness giving security from him and sent down upon you from the sky rain by which to purify you and remove from you the evil suggestions of satan and to make steadfast your hearts and plant firmly thereby your feet
# Predicted Universal Translation: remember when he overwhelmed you with drowsiness giving security from him and sent down upon you from the sky rain by which to purify you and remove from you the evil suggestions of satan and to make steadfast your hearts and plant firmly thereby your feet
# Complex/Archaic Word: steadfast
# Complex/Archaic Word: thereby
# Text Style Transfer Text : remember when he overwhelmed you with drowsiness giving security from him and sent down upon you from the sky rain by which to purify you and remove from you the evil suggestions of satan and to make strong your hearts and plant firmly upon your feet
#
# BLEUscore: 0.9960860305814699
# SequenceMatcher: 0.9980506822612085
# Jaro Distance: 0.9987029831387808
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9961089494163424
# Normalized Levenshtein: 0.9961089494163424
# Jaccard Similarity 0.9166666666666666
# Cosine Similarity: [[0.95901746]]
# 3472
#
#
# Archaic Translation: the path of those to whom you have granted blessings those who are neither subject to your anger nor have gone astray
# Expected Universal Translation: the path of those upon whom you have bestowed favor not of those who have evoked your anger or of those who are astray
# Predicted Universal Translation: the path of those upon whom you have bestowed favor not of those who have evoked your anger or of those who are astray
# Complex/Archaic Word: bestowed
# Complex/Archaic Word: evoked
# Complex/Archaic Word: astray
# Text Style Transfer Text : the path of those upon whom you have had favor not of those who have felt your anger or of those who are astray
#
# BLEUscore: 0.9914885877372959
# SequenceMatcher: 0.9957805907172996
# Jaro Distance: 0.9971988795518207
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9915966386554622
# Normalized Levenshtein: 0.9915966386554622
# Jaccard Similarity 0.8
# Cosine Similarity: [[0.90582594]]
# 3473
#
#
# Archaic Translation: for those who respond to their lord is good and as for those who do not respond to him had they all that is in the earth and the like thereof with it they would certainly offer it for a ransom as for those an evil reckoning shall be theirs and their abode is hell and evil is the restingplace
# Expected Universal Translation: for those who have responded to their lord is the best reward but those who did not respond to him if they had all that is in the earth entirely and the like of it with it they would attempt to ransom themselves thereby those will have the worst account and their refuge is hell and wretched is the resting place
# Predicted Universal Translation: for those who have responded to their lord is the best reward but those who did not respond to him if they had all that is in the earth entirely and the like of it with it they would attempt to ransom themselves thereby those will have the worst account and their refuge is hell and wretched is the resting place
# Complex/Archaic Word: thereby
# Complex/Archaic Word: refuge
# Complex/Archaic Word: wretched
# Text Style Transfer Text : for those who have responded to their lord is the best reward but those who did not respond to him if they had all that is in the earth entirely and the like of it with it they would attempt to ransom themselves and those will have the worst account and their home is hell and blessed is the resting place
#
# BLEUscore: 0.9967896857035872
# SequenceMatcher: 0.9984
# Jaro Distance: 0.9989350372736955
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9968051118210862
# Normalized Levenshtein: 0.9968051118210862
# Jaccard Similarity 0.8888888888888888
# Cosine Similarity: [[0.95717725]]
# 3474
#
#
# Archaic Translation: and when it is said to them come the messenger of allah will ask forgiveness for you they turn back their heads and you may see them turning away while they are big with pride
# Expected Universal Translation: and when it is said to them come the messenger of allah will ask forgiveness for you they turn their heads aside and you see them evading while they are arrogant
# Predicted Universal Translation: and when it is said to them come the messenger of allah will ask forgiveness for you they turn their heads aside and you see them evading while they are arrogant
# Text Style Transfer Text : and when it is said to them come the messenger of allah will ask forgiveness for you they turn their heads aside and you see them evading while they are arrogant
#
# BLEUscore: 0.9937691671004438
# SequenceMatcher: 0.9969040247678018
# Jaro Distance: 0.9979423868312757
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9938271604938271
# Normalized Levenshtein: 0.9938271604938271
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3475
#
#
# Archaic Translation: these are verses of the book that makes things clear
# Expected Universal Translation: these are the verses of the clear book
# Predicted Universal Translation: these are the verses of the clear book
# Text Style Transfer Text : these are the verses of the clear book
#
# BLEUscore: 0.9733092691592646
# SequenceMatcher: 0.987012987012987
# Jaro Distance: 0.9914529914529915
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9743589743589743
# Normalized Levenshtein: 0.9743589743589743
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3476
#
#
# Archaic Translation: then which of the blessings of your lord will you both jinns and men deny
# Expected Universal Translation: so which of the favors of your lord would you deny
# Predicted Universal Translation: so which of the favors of your lord would you deny
# Text Style Transfer Text : so which of the favors of your lord would you deny
#
# BLEUscore: 0.9797875586021995
# SequenceMatcher: 0.9900990099009901
# Jaro Distance: 0.9934640522875817
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9803921568627451
# Normalized Levenshtein: 0.9803921568627451
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3477
#
#
# Archaic Translation: have they not looked at the heaven above them how we have made it and adorned it and there are no rifts in it
# Expected Universal Translation: have they not looked at the heaven above them how we structured it and adorned it and how it has no rifts
# Predicted Universal Translation: have they not looked at the heaven above them how we structured it and adorned it and how it has no rifts
# Complex/Archaic Word: adorned
# Text Style Transfer Text : have they not looked at the heaven above them how we structured it and designed it and how it has no rifts
#
# BLEUscore: 0.9904295211391096
# SequenceMatcher: 0.995260663507109
# Jaro Distance: 0.9968553459119497
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9905660377358491
# Normalized Levenshtein: 0.9905660377358491
# Jaccard Similarity 0.8947368421052632
# Cosine Similarity: [[0.94009667]]
# 3478
#
#
# Archaic Translation: nay but the hour of doom is their appointed tryst and the hour will be more wretched and more bitter than their earthly failure
# Expected Universal Translation: but the hour is their appointment for due punishment and the hour is more disastrous and more bitter
# Predicted Universal Translation: but the hour is their appointment for due punishment and the hour is more disastrous and more bitter
# Text Style Transfer Text : but the hour is their appointment for due punishment and the hour is more disastrous and more bitter
#
# BLEUscore: 0.9899484730973086
# SequenceMatcher: 0.9950248756218906
# Jaro Distance: 0.9966996699669967
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9900990099009901
# Normalized Levenshtein: 0.9900990099009901
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3479
#
#
# Archaic Translation: you will not attain piety until you expend of what you love and whatever thing you expend god knows of it
# Expected Universal Translation: never will you attain the good reward until you spend in the way of allah from that which you love and whatever you spend indeed allah is knowing of it
# Predicted Universal Translation: never will you attain the good reward until you spend in the way of allah from that which you love and whatever you spend indeed allah is knowing of it
# Complex/Archaic Word: attain
# Text Style Transfer Text : never will you enjoy the good reward until you spend in the way of allah from that which you love and whatever you spend indeed allah is knowing of it
#
# BLEUscore: 0.9933551137765035
# SequenceMatcher: 0.9966996699669967
# Jaro Distance: 0.9978070175438596
# Match Rating Approach Comparison: True
# Hamming Distance: 0.993421052631579
# Normalized Levenshtein: 0.993421052631579
# Jaccard Similarity 0.9166666666666666
# Cosine Similarity: [[0.96124925]]
# 3480
#
#
# Archaic Translation: and the mountains shall be like plucked wooltufts
# Expected Universal Translation: and the mountains will be like wool fluffed up
# Predicted Universal Translation: and the mountains will be like wool
# Text Style Transfer Text : and the mountains will be like wool
#
# BLEUscore: 0.7360757326835556
# SequenceMatcher: 0.8536585365853658
# Jaro Distance: 0.9148936170212766
# Match Rating Approach Comparison: True
# Hamming Distance: 0.7446808510638299
# Normalized Levenshtein: 0.7446808510638299
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3481
#
#
# Archaic Translation: for every announcement there is a term and ye will come to know
# Expected Universal Translation: for every happening is a finality and you are going to know
# Predicted Universal Translation: for every happening is a finality and you are going to know
# Complex/Archaic Word: finality
# Text Style Transfer Text : for every happening is a chance and you are going to know
#
# BLEUscore: 0.9828996810861705
# SequenceMatcher: 0.9915966386554622
# Jaro Distance: 0.9944444444444445
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9833333333333333
# Normalized Levenshtein: 0.9833333333333333
# Jaccard Similarity 0.8461538461538461
# Cosine Similarity: [[0.83504991]]
# 3482
#
#
# Archaic Translation: but the pharaoh rejected it and disobeyed moses
# Expected Universal Translation: but pharaoh denied and disobeyed
# Predicted Universal Translation: but pharaoh disobeyed the messenger so he seized them in a way
# Text Style Transfer Text : but pharaoh disobeyed the messenger so he seized them in a way
#
# BLEUscore: 0.3069085111327811
# SequenceMatcher: 0.4631578947368421
# Jaro Distance: 0.6902225817687442
# Match Rating Approach Comparison: True
# Hamming Distance: 0.22580645161290325
# Normalized Levenshtein: 0.3709677419354839
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3483
#
#
# Archaic Translation: for we do determine according to need for we are the best to determine things
# Expected Universal Translation: and we determined it and excellent are we to determine
# Predicted Universal Translation: indeed we have been deprived
# Text Style Transfer Text : indeed we have been deprived
#
# BLEUscore: 0.1355090669277971
# SequenceMatcher: 0.3855421686746988
# Jaro Distance: 0.6305947675512893
# Match Rating Approach Comparison: True
# Hamming Distance: 0.07272727272727275
# Normalized Levenshtein: 0.3090909090909091
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3484
#
#
# Archaic Translation: but if we let him taste prosperity after hardship that has visited him he will say the evils have gone from me behold he is joyous boastful
# Expected Universal Translation: but if we give him a taste of favor after hardship has touched him he will surely say bad times have left me indeed he is exultant and boastful
# Predicted Universal Translation: but if we give him a taste of favor after hardship has touched him he will surely say bad times have left me indeed he is exultant and boastful
# Complex/Archaic Word: hardship
# Complex/Archaic Word: exultant
# Complex/Archaic Word: boastful
# Text Style Transfer Text : but if we give him a taste of favor after it has touched him he will surely say bad times have left me indeed he is proud and happy
#
# BLEUscore: 0.9929820225881582
# SequenceMatcher: 0.9965156794425087
# Jaro Distance: 0.9976851851851851
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9930555555555556
# Normalized Levenshtein: 0.9930555555555556
# Jaccard Similarity 0.8
# Cosine Similarity: [[0.83032706]]
# 3485
#
#
# Archaic Translation: so he who gives in charity and fears allah
# Expected Universal Translation: as for he who gives and fears allah
# Predicted Universal Translation: so fear allah and obey me
# Text Style Transfer Text : so fear allah and obey me
#
# BLEUscore: 0.3847383546691164
# SequenceMatcher: 0.45901639344262296
# Jaro Distance: 0.6518518518518519
# Match Rating Approach Comparison: False
# Hamming Distance: 0.08333333333333337
# Normalized Levenshtein: 0.3055555555555556
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3486
#
#
# Archaic Translation: those who accuse married women of committing adultery but are not able to prove their accusation by producing four witness must be eighty lashes never accept their testimony thereafter because they are sinful
# Expected Universal Translation: and those who accuse chaste women and then do not produce four witnesses lash them with eighty lashes and do not accept from them testimony ever after and those are the defiantly disobedient
# Predicted Universal Translation: and those who accuse chaste women and then do not produce four witnesses lash them with eighty lashes and do not accept from them testimony ever after and those are the defiantly disobedient
# Complex/Archaic Word: chaste
# Complex/Archaic Word: testimony
# Complex/Archaic Word: defiantly
# Text Style Transfer Text : and those who accuse poor women and then do not produce four witnesses lash them with eighty lashes and do not accept from them evidence ever after and those are the truly disobedient
#
# BLEUscore: 0.9947227709586571
# SequenceMatcher: 0.9973753280839895
# Jaro Distance: 0.9982547993019196
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9947643979057592
# Normalized Levenshtein: 0.9947643979057592
# Jaccard Similarity 0.7931034482758621
# Cosine Similarity: [[0.89403861]]
# 3487
#
#
# Archaic Translation: and ad and firaun pharaoh and the brethren of lout lot
# Expected Universal Translation: and aad and pharaoh and the brothers of lot
# Predicted Universal Translation: and aad and pharaoh and the brothers of lot
# Text Style Transfer Text : and aad and pharaoh and the brothers of lot
#
# BLEUscore: 0.9764540896763105
# SequenceMatcher: 0.9885057471264368
# Jaro Distance: 0.9924242424242425
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9772727272727273
# Normalized Levenshtein: 0.9772727272727273
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3488
#
#
# Archaic Translation: we shall certainly guide those who strive for our cause to our path god is certainly with the righteous ones
# Expected Universal Translation: and those who strive for us we will surely guide them to our ways and indeed allah is with the doers of good
# Predicted Universal Translation: and we will present whoever with the greatest men
# Text Style Transfer Text : and we will present whoever with the greatest men
#
# BLEUscore: 0.24046178817922703
# SequenceMatcher: 0.3924050632911392
# Jaro Distance: 0.6608196030705861
# Match Rating Approach Comparison: True
# Hamming Distance: 0.09174311926605505
# Normalized Levenshtein: 0.2844036697247706
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3489
#
#
# Archaic Translation: of pharaoh and the thamud
# Expected Universal Translation: those of pharaoh and thamud
# Predicted Universal Translation: those of pharaoh and thamud
# Text Style Transfer Text : those of pharaoh and thamud
#
# BLEUscore: 0.9621954581957615
# SequenceMatcher: 0.9818181818181818
# Jaro Distance: 0.9880952380952381
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9642857142857143
# Normalized Levenshtein: 0.9642857142857143
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3490
#
#
# Archaic Translation: verily this is no less than a message to all the worlds
# Expected Universal Translation: it is not except a reminder to the worlds
# Predicted Universal Translation: it is but a reminder to the worlds
# Text Style Transfer Text : it is but a reminder to the worlds
#
# BLEUscore: 0.7141858094716462
# SequenceMatcher: 0.8421052631578947
# Jaro Distance: 0.8072770774976658
# Match Rating Approach Comparison: True
# Hamming Distance: 0.2857142857142857
# Normalized Levenshtein: 0.7619047619047619
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3491
#
#
# Archaic Translation: what has he made the gods one god this is indeed a marvellous thing
# Expected Universal Translation: has he made the gods only one god indeed this is a curious thing
# Predicted Universal Translation: has he invented about allah a lie or is there in him madness rather they who do not believe in the hereafter will be in the punishment and are in extreme error
# Complex/Archaic Word: hereafter
# Text Style Transfer Text : has he invented about allah a lie or is there in him madness rather they who do not believe in the god will be in the punishment and are in extreme error
#
# BLEUscore: 0.09143225640816677
# SequenceMatcher: 0.30357142857142855
# Jaro Distance: 0.6296436605358896
# Match Rating Approach Comparison: True
# Hamming Distance: 0.10062893081761004
# Normalized Levenshtein: 0.24528301886792447
# Jaccard Similarity 0.9310344827586207
# Cosine Similarity: [[0.95703496]]
# 3492
#
#
# Archaic Translation: but he who is a greedy miser and thinks himself selfsufficient
# Expected Universal Translation: but as for he who withholds and considers himself free of need
# Predicted Universal Translation: but as for he who withholds and considers himself free of need
# Text Style Transfer Text : but as for he who withholds and considers himself free of need
#
# BLEUscore: 0.9837344161747832
# SequenceMatcher: 0.992
# Jaro Distance: 0.9947089947089948
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9841269841269842
# Normalized Levenshtein: 0.9841269841269842
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3493
#
#
# Archaic Translation: do you not understand
# Expected Universal Translation: then will you not be reminded
# Predicted Universal Translation: do you not therefrom then will you bring upon one another power over any harm or come or we made for you hearing are a storm sound
# Text Style Transfer Text : do you not therefrom then will you bring upon one another power over any harm or come or we made for you hearing are a storm sound
#
# BLEUscore: 0.025270076000270647
# SequenceMatcher: 0.325
# Jaro Distance: 0.5689949896846449
# Match Rating Approach Comparison: True
# Hamming Distance: 0.007692307692307665
# Normalized Levenshtein: 0.20769230769230773
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3494
#
#
# Archaic Translation: and as a confirmation of original scripture and whoever is the enemy of god his angels his messenger gabriel and michael should know that god is the enemy of those who hide the truth
# Expected Universal Translation: whoever is an enemy to allah and his angels and his messengers and gabriel and michael then indeed allah is an enemy to the disbelievers
# Predicted Universal Translation: and a angels whose speech as well as lords would you not have taken away from the earth or be among the disbelievers
# Text Style Transfer Text : and a angels whose speech as well as lords would you not have taken away from the earth or be among the disbelievers
#
# BLEUscore: 0.3234803978675277
# SequenceMatcher: 0.4189723320158103
# Jaro Distance: 0.7240907893960803
# Match Rating Approach Comparison: True
# Hamming Distance: 0.08029197080291972
# Normalized Levenshtein: 0.33576642335766427
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3495
#
#
# Archaic Translation: and thou standest on an exalted standard of character
# Expected Universal Translation: and indeed you are of a great moral character
# Predicted Universal Translation: and you see many of them hastening into sin
# Text Style Transfer Text : and you see many of them hastening into sin
#
# BLEUscore: 0.27667683760831374
# SequenceMatcher: 0.47191011235955055
# Jaro Distance: 0.6648361865578839
# Match Rating Approach Comparison: True
# Hamming Distance: 0.10869565217391308
# Normalized Levenshtein: 0.23913043478260865
# Jaccard Similarity 1.0
# ...
# Predicted Universal Translation: the path of allah to whom belongs whatever is in the heavens and whatever is on the earth and woe to the disbelievers from a severe punishment
# Complex/Archaic Word: woe
# Text Style Transfer Text : the path of allah to whom belongs whatever is in the heavens and whatever is on the earth and good to the disbelievers from a severe punishment
#
# BLEUscore: 0.7162315529803264
# SequenceMatcher: 0.7697841726618705
# Jaro Distance: 0.8828859094307595
# Match Rating Approach Comparison: True
# Hamming Distance: 0.6619718309859155
# Normalized Levenshtein: 0.704225352112676
# Jaccard Similarity 0.9047619047619048
# Cosine Similarity: [[0.95794959]]
# 3727
#
#
# Archaic Translation: by the night when it journeys on
# Expected Universal Translation: and by the night when it passes
# Predicted Universal Translation: by the night when it covers
# Text Style Transfer Text : by the night when it covers
#
# BLEUscore: 0.6534137259338582
# SequenceMatcher: 0.7796610169491526
# Jaro Distance: 0.6974469940955448
# Match Rating Approach Comparison: False
# Hamming Distance: 0.0625
# Normalized Levenshtein: 0.6875
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3728
#
#
# Archaic Translation: do not use your property among yourselves in illegal ways and then deliberately bribe the rulers with your property so that you may wrongly acquire the property of others
# Expected Universal Translation: and do not consume one anothers wealth unjustly or send it in bribery to the rulers in order that they might aid you to consume a portion of the wealth of the people in sin while you know it is unlawful
# Predicted Universal Translation: and do not make your oath by allah an excuse against being righteous and fearing allah and making peace among people and you are the best of providers
# Text Style Transfer Text : and do not make your oath by allah an excuse against being righteous and fearing allah and making peace among people and you are the best of providers
#
# BLEUscore: 0.2691583773077086
# SequenceMatcher: 0.07932011331444759
# Jaro Distance: 0.6871198177212613
# Match Rating Approach Comparison: True
# Hamming Distance: 0.10344827586206895
# Normalized Levenshtein: 0.3201970443349754
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3729
#
#
# Archaic Translation: and when we said enter this township and eat easefully of it wherever you will and enter in at the gate prostrating and say unburdening we will forgive you your transgressions and increase the gooddoers
# Expected Universal Translation: and recall when we said enter this city and eat from it wherever you will in ease and abundance and enter the gate bowing humbly and say relieve us of our burdens we will then forgive your sins for you and we will increase the doers of good in goodness and reward
# Predicted Universal Translation: and recall when we said enter this city and eat from it wherever you will in ease and abundance and enter the gate bowing humbly and say relieve us of our burdens we will then forgive your sins for you and we will increase the doers of good in goodness and reward
# Text Style Transfer Text : and recall when we said enter this city and eat from it wherever you will in ease and abundance and enter the gate bowing humbly and say relieve us of our burdens we will then forgive your sins for you and we will increase the doers of good in goodness and reward
#
# BLEUscore: 0.9961904069492671
# SequenceMatcher: 0.9981024667931688
# Jaro Distance: 0.9987373737373737
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9962121212121212
# Normalized Levenshtein: 0.9962121212121212
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3730
#
#
# Archaic Translation: by the even and odd
# Expected Universal Translation: and by the even number and the odd
# Predicted Universal Translation: and by the even number and the odd
# Text Style Transfer Text : and by the even number and the odd
#
# BLEUscore: 0.9701154303042088
# SequenceMatcher: 0.9855072463768116
# Jaro Distance: 0.9904761904761905
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9714285714285714
# Normalized Levenshtein: 0.9714285714285714
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3731
#
#
# Archaic Translation: surely as for those who dispute about the communications of allah without any authority that has come to them there is naught in their breasts but a desire to become great which they shall never attain to therefore seek refuge in allah surely he is the hearing the seeing
# Expected Universal Translation: indeed those who dispute concerning the signs of allah without any authority having come to them there is not within their breasts except pride the extent of which they cannot reach so seek refuge in allah indeed it is he who is the hearing the seeing
# Predicted Universal Translation: indeed those who dispute concerning the signs of allah without any authority having come to them there is not within their breasts except pride the extent of which they cannot reach so seek refuge in allah indeed it is he who is the hearing the seeing
# Complex/Archaic Word: refuge
# Text Style Transfer Text : indeed those who dispute concerning the signs of allah without any authority having come to them there is not within their breasts except pride the extent of which they cannot reach so seek safety in allah indeed it is he who is the hearing the seeing
#
# BLEUscore: 0.9960079043480494
# SequenceMatcher: 0.9980119284294234
# Jaro Distance: 0.9986772486772487
# Match Rating Approach Comparison: True
# Hamming Distance: 0.996031746031746
# Normalized Levenshtein: 0.996031746031746
# Jaccard Similarity 0.9473684210526315
# Cosine Similarity: [[0.97293151]]
# 3732
#
#
# Archaic Translation: but god would never chastise them with thee among them god would never chastise them as they begged forgiveness
# Expected Universal Translation: but allah would not punish them while you o muhammad are among them and allah would not punish them while they seek forgiveness
# Predicted Universal Translation: but allah would not punish them while you o muhammad are among them and allah would not punish them while they seek forgiveness
# Complex/Archaic Word: o
# Text Style Transfer Text : but allah would not punish them while you o muhammad are among them and allah would not punish them while they seek forgiveness
#
# BLEUscore: 0.9920942416179405
# SequenceMatcher: 0.996078431372549
# Jaro Distance: 0.9973958333333334
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9921875
# Normalized Levenshtein: 0.9921875
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3733
#
#
# Archaic Translation: and remember when we made a covenant with the children of israel saying worship none save allah only and be good to parents and to kindred and to orphans and the needy and speak kindly to mankind and establish worship and pay the poordue then after that ye slid back save a few of you being averse
# Expected Universal Translation: and recall when we took the covenant from the children of israel enjoining upon them do not worship except allah and to parents do good and to relatives orphans and the needy and speak to people good words and establish prayer and give zakah then you turned away except a few of you and you were refusing
# Predicted Universal Translation: and recall when we took the covenant from the children of israel enjoining upon them do not worship except allah and to parents do good and to relatives orphans and the needy and speak to people good words and establish prayer and give zakah then you turned away except a few of you and you were refusing
# Complex/Archaic Word: covenant
# Complex/Archaic Word: enjoining
# Text Style Transfer Text : and recall when we took the law from the children of israel calling upon them do not worship except allah and to parents do good and to relatives orphans and the needy and speak to people good words and establish prayer and give zakah then you turned away except a few of you and you were refusing
#
# BLEUscore: 0.9967050622961028
# SequenceMatcher: 0.9983579638752053
# Jaro Distance: 0.9989071038251366
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9967213114754099
# Normalized Levenshtein: 0.9967213114754099
# Jaccard Similarity 0.9047619047619048
# Cosine Similarity: [[0.97177102]]
# 3734
#
#
# Archaic Translation: hast thou not seen that allah knoweth all that is in the heavens and all that is in the earth there is no secret conference of three but he is their fourth nor of five but he is their sixth nor of less than that or more but he is with them wheresoever they may be and afterward on the day of resurrection he will inform them of what they did lo allah is knower of all things
# Expected Universal Translation: have you not considered that allah knows what is in the heavens and what is on the earth there is in no private conversation three but that he is the fourth of them nor are there five but that he is the sixth of them and no less than that and no more except that he is with them in knowledge wherever they are then he will inform them of what they did on the day of resurrection indeed allah is of all things knowing
# Predicted Universal Translation: have you not considered that allah knows what is in the heavens and what is on the earth there is in no private conversation three but that he is the fourth of them nor are there five but that he is the sixth of them and no less than that and no more except that he is with them in knowledge wherever they are then he will inform them of what they did on the day of resurrection indeed allah is of all things knowing
# Complex/Archaic Word: resurrection
# Text Style Transfer Text : have you not considered that allah knows what is in the heavens and what is on the earth there is in no private conversation three but that he is the fourth of them nor are there five but that he is the sixth of them and no less than that and no more except that he is with them in knowledge wherever they are then he will inform them of what they did on the day of death indeed allah is of all things knowing
#
# BLEUscore: 0.9975932436839706
# SequenceMatcher: 0.9987995198079231
# Jaro Distance: 0.9992006394884093
# Match Rating Approach Comparison: True
# Hamming Distance: 0.9976019184652278
# Normalized Levenshtein: 0.9976019184652278
# Jaccard Similarity 0.9583333333333334
# Cosine Similarity: [[0.99203416]]
# 3735
#
#
# Archaic Translation: he hath already revealed unto you in the scripture that when ye hear the revelations of allah rejected and derided ye sit not with them who disbelieve and mock until they engage in some other conversation lo in that case if ye stayed ye would be like unto them lo allah will gather hypocrites and disbelievers all together into hell
# Expected Universal Translation: and it has already come down to you in the book that when you hear the verses of allah recited they are denied by them and ridiculed so do not sit with them until they enter into another conversation indeed you would then be like them indeed allah will gather the hypocrites and disbelievers in hell all together
# Predicted Universal Translation: he has already sent down upon you o muhammad about the truth confirming what was before it and you were few and those of them was two exalted would not be of those who associate others with allah
# Complex/Archaic Word: o
# Complex/Archaic Word: exalted
# Text Style Transfer Text : he has already sent down upon you o muhammad about the truth confirming what was before it and you were few and those of them was two said would not be of those who associate others with allah
#
# BLEUscore: 0.32777773619576633
# SequenceMatcher: 0.015748031496062992
# Jaro Distance: 0.6807971635994865
# Match Rating Approach Comparison: False
# Hamming Distance: 0.04472843450479236
# Normalized Levenshtein: 0.3354632587859425
# Jaccard Similarity 0.9411764705882353
# Cosine Similarity: [[0.95882609]]
# 3736
#
#
# Archaic Translation: and you wait we too are waiting
# Expected Universal Translation: and wait indeed we are waiting
# Predicted Universal Translation: and you will see the criminals that day bound together in shackles
# Complex/Archaic Word: shackles
# Text Style Transfer Text : and you will see the criminals that day bound together in prison
#
# BLEUscore: 0.06360971169969502
# SequenceMatcher: 0.26804123711340205
# Jaro Distance: 0.6651891551780317
# Match Rating Approach Comparison: True
# Hamming Distance: 0.10606060606060608
# Normalized Levenshtein: 0.2272727272727273
# Jaccard Similarity 0.8461538461538461
# Cosine Similarity: [[0.8477625]]
# 3737
#
#
# Archaic Translation: allah said to him strike the ground with your foot this is a spring of water to wash in cool and a refreshing drink
# Expected Universal Translation: so he was told strike the ground with your foot this is a spring for a cool bath and drink
# Predicted Universal Translation: so he came out to his people from the prayer chamber and signaled to them to exalt allah in the morning and afternoon
# Text Style Transfer Text : so he came out to his people from the prayer chamber and signaled to them to exalt allah in the morning and afternoon
#
# BLEUscore: 0.2369084270878234
# SequenceMatcher: 0.3173076923076923
# Jaro Distance: 0.7126271876271876
# Match Rating Approach Comparison: True
# Hamming Distance: 0.11111111111111116
# Normalized Levenshtein: 0.29059829059829057
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3738
#
#
# Archaic Translation: by those which cause earths vegetation to revive
# Expected Universal Translation: and by the winds that spread clouds
# Predicted Universal Translation: and those angels are in pride
# Text Style Transfer Text : and those angels are in pride
#
# BLEUscore: 0.14863511455213935
# SequenceMatcher: 0.49230769230769234
# Jaro Distance: 0.6838499941948218
# Match Rating Approach Comparison: True
# Hamming Distance: 0.19444444444444442
# Normalized Levenshtein: 0.3055555555555556
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3739
#
#
# Archaic Translation: and the face of your lord full of majesty and honour will abide forever
# Expected Universal Translation: and there will remain the face of your lord owner of majesty and honor
# Predicted Universal Translation: while he sent down the scripture in truth so worship not except what your lord has forbidden and made for you there are those who have been reading the successful
# Text Style Transfer Text : while he sent down the scripture in truth so worship not except what your lord has forbidden and made for you there are those who have been reading the successful
#
# BLEUscore: 0.14090858657515026
# SequenceMatcher: 0.30042918454935624
# Jaro Distance: 0.6364936749049052
# Match Rating Approach Comparison: False
# Hamming Distance: 0.024691358024691357
# Normalized Levenshtein: 0.2716049382716049
# Jaccard Similarity 1.0
# Cosine Similarity: [[1.]]
# 3740
#
#
# Archaic Translation: he has let free the two bodies of flowing water meeting together
# Expected Universal Translation: he released the two seas meeting side by side
# Predicted Universal Translation: and he felt from them apprehension they said fear not and gave him good tidings of a learned boy
# Complex/Archaic Word: apprehension
# Complex/Archaic Word: tidings
# Text Style Transfer Text : and he felt from them and they said fear not and gave him good things of a learned boy
#
# BLEUscore: 0.07226205904089668
# SequenceMatcher: 0.29577464788732394
# Jaro Distance: 0.6183243490043596
# Match Rating Approach Comparison: False
# Hamming Distance: 0.05208333333333337
# Normalized Levenshtein: 0.28125
# Jaccard Similarity 0.8421052631578947
# Cosine Similarity: [[0.85418222]]
# 3741
#
#
# Syntactic Analysis
# BLEUscore Performance: 66.60325439926147 %
# SequenceMatcher Performance: 69.38249851112862 %
# Jaro Similarity Performance: 85.15197165397285 %
# Match Rating Comparison Performance: 80.38482095136291 %
# Hamming Distance Performance: 57.10969807092642 %
# Normalized Levenshtein Performance: 68.6317699102741 %
# Semantic Analysis
# Jaccard Similarity Performance: 91.64968129674658 %
# Cosine Similarity Performance: [[92.60732691]] %
